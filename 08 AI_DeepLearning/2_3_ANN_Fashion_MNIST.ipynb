# %% [markdown]
# # ANN & Fashion MNIST
#
# <br> By Margaret Maynard-Reid, 4/24/2018
#
# ![alt text](https://github.com/margaretmz/deep-learning/blob/master/images/modern%20dl_fash-mnist_keras.png?raw=1)

# %% [markdown]
# ## Why Fashion-MNIST?
#
#
# *   MNIST is too easy
# *   MNIST is overused
# *   MNIST can not represent modern Computer Vision tasks
#
# Read more about the Fashion-MINST dataset in this paper [here](https://arxiv.org/abs/1708.07747) (**Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning Algorithms**)

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# Load the fashion-mnist pre-shuffled train data and test data
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28) y_train shape: (60000,)

# %% [markdown]
# ## Visualize the data 반복실행 해보자

# %%
# Print training set shape - note there are 60,000 training data of image size of 28x28, 60,000 train labels)
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training and test datasets
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'test set')

# Define the text labels
fashion_mnist_labels = ["T-shirt/top",  # index 0
                        "Trouser",      # index 1
                        "Pullover",     # index 2 
                        "Dress",        # index 3 
                        "Coat",         # index 4
                        "Sandal",       # index 5
                        "Shirt",        # index 6 
                        "Sneaker",      # index 7 
                        "Bag",          # index 8 
                        "Ankle boot"]   # index 9

# Image index, you can pick any number between 0 and 59,999
img_index = np.random.randint(0, 59999)
# y_train contains the lables, ranging from 0 to 9
label_index = y_train[img_index]
# Print the label, for example 2 Pullover
print ("y = " + str(label_index) + " " +(fashion_mnist_labels[label_index]))
# # Show one of the images from the training dataset
plt.imshow(x_train[img_index])
# Out:
# x_train shape: (60000, 28, 28) y_train shape: (60000,)
# 60000 train set
# 10000 test set
# y = 2 Pullover

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28) (60000,) (10000,)

# %% [markdown]
# ##  코딩 task!
#
# 1. 전처리
#     * x : sc_____
#     * y : _______ encoding
#
# 2. 모델링
#     * model에 모델 선언
#     * Input layer에 어떻게 전달할 것인지 고민 필요
#     * 쭈우우우욱 늘려주는 레이어를 사용할 것 (F______)
#     * 히든레이어는 최소 3개를 쓸 것!
#     * 노드 수는 512개를 기본으로 시작
#     * 자유롭게 바꿔가며 성능을 볼 것
#
# 3. 학습
#     * epochs=50, validation_split=0.2
#     * early stopping

# %%
# 1. scaling
max_n, min_n = x_train.max(), x_train.min()
x_train = (max_n - x_train) / (max_n - min_n)

print(f'x_train max: {x_train.max()}, min: {x_train.min()}')
# Out:
# x_train max: 1.0, min: 0.0

# %%
# 2. one-hot encoding
from tensorflow.keras.utils import to_categorical

class_n = len(set(y_train))
y_train = to_categorical(y_train, class_n)

# %%
# shape 확인
x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000, 10))

# %%
# 3. 모델링
keras.backend.clear_session()

model = keras.models.Sequential()

model.add(keras.layers.Input(shape=(28, 28)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(512, activation='relu'))
model.add(keras.layers.Dense(512, activation='relu'))
model.add(keras.layers.Dense(512, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

model.compile('adam', loss='categorical_crossentropy', metrics='accuracy')

# 모델 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 932,362
# Trainable params: 932,362
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Early Stopping
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss',        
                   min_delta=0,               
                   patience=5,                
                   verbose=1,
                   restore_best_weights=True)

# %%
# 4. 학습
model.fit(x_train, y_train, validation_split=0.2, callbacks=[es], verbose=1, epochs=50)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 7s 3ms/step - loss: 0.6345 - accuracy: 0.7645 - val_loss: 0.4943 - val_accuracy: 0.8152
# Epoch 2/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4904 - accuracy: 0.8191 - val_loss: 0.4792 - val_accuracy: 0.8148
# Epoch 3/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4487 - accuracy: 0.8349 - val_loss: 0.4587 - val_accuracy: 0.8372
# Epoch 4/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4191 - accuracy: 0.8444 - val_loss: 0.4435 - val_accuracy: 0.8375
# Epoch 5/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3948 - accuracy: 0.8531 - val_loss: 0.3974 - val_accuracy: 0.8548
# Epoch 6/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3791 - accuracy: 0.8601 - val_loss: 0.4440 - val_accuracy: 0.8343
# Epoch 7/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3635 - accuracy: 0.8646 - val_loss: 0.3694 - val_accuracy: 0.8645
# Epoch 8/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3566 - accuracy: 0.8680 - val_loss: 0.3812 - val_accuracy: 0.8550
# Epoch 9/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3425 - accuracy: 0.8725 - val_loss: 0.3817 - val_accuracy: 0.8624
# Epoch 10/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3348 - accuracy: 0.8752 - val_loss: 0.3682 - val_accuracy: 0.8626
# Epoch 11/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3224 - accuracy: 0.8795 - val_loss: 0.3608 - val_accuracy: 0.8676
# Epoch 12/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3169 - accuracy: 0.8803 - val_loss: 0.3575 - val_accuracy: 0.8735
# Epoch 13/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3109 - accuracy: 0.8825 - val_loss: 0.3794 - val_accuracy: 0.8692
# Epoch 14/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3074 - accuracy: 0.8837 - val_loss: 0.3675 - val_accuracy: 0.8689
# Epoch 15/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2981 - accuracy: 0.8875 - val_loss: 0.3886 - val_accuracy: 0.8629
# Epoch 16/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2931 - accuracy: 0.8899 - val_loss: 0.3761 - val_accuracy: 0.8650
# Epoch 17/50
# 1496/1500 [============================>.] - ETA: 0s - loss: 0.2865 - accuracy: 0.8923Restoring model weights from the end of the best epoch: 12.
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2868 - accuracy: 0.8924 - val_loss: 0.3930 - val_accuracy: 0.8695
# Epoch 17: early stopping

# %% [markdown]
# ## Visualize prediction
#
# 위에서 지키라고 한 사항들 안지키면 동작을 안할껄...?

# %%
y_test = to_categorical(y_test, class_n)
score = model.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model.predict(x_test).argmax(axis=1)
# Out:
#  Test accuracy: 0.002300000051036477

# %%
####### 반복실행해보자

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index].reshape([28,-1]) ) )
    predict_index = y_hat[index]
    true_index = y_test[index].argmax(axis=0)
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
