# %% [markdown]
# # 1일차 Review : 같은 문제 다시 풀어보기
#
#     학습은 10번으로!

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
x = boston.data
y = boston.target

# %%
x.shape, y.shape
# Out:
# ((506, 13), (506,))

# %%
#####################
# 라이브러리 불러오기
#####################
import tensorflow as tf
from tensorflow import keras

# %%
########
# 모델링
########
keras.backend.clear_session()

model = keras.models.Sequential()
model.add(keras.layers.Dense(1, input_shape=(13,)))
model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 14
#
# =================================================================
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 1s 2ms/step - loss: 1455.5660
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 775.4954
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 487.9706
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 407.2758
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 389.1939
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 376.0274
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 363.3837
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 352.6377
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 341.3229
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 330.5660

# %%
###########
# 모델 예측
###########
y_pred = model.predict(x).reshape(-1)
print(y_pred[:10])
# Out:
# [20.841791   4.5840507 14.482676  19.649982  15.162635  12.44199
#  19.092735   3.2482128 -0.7112936  8.551096 ]

# %% [markdown]
# # 히든 레이어 추가하여 모델링!
#
#     히든 레이어 2개를 추가하여 다시 모델링!
#     히든 레이어 노드 수 : 32
#     히든 레이어 activation = 'relu'

# %%
########
# 모델링
########
keras.backend.clear_session()

model = keras.models.Sequential()

model.add(keras.layers.Input(shape=(13,)))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1))

model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                448
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,537
# Trainable params: 1,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 602.5723
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 98.5483
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 78.4477
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 57.6964
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 54.5755
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 55.2794
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 50.8107
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 50.7526
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 48.4395
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 47.3100

# %%
###########
# 모델 예측
###########
y_pred = model.predict(x).reshape(-1)
print(y_pred[:10])
# Out:
# [28.125679 27.367092 28.308777 28.091713 27.74729  27.99905  25.237507
#  24.492825 21.006712 23.372084]
