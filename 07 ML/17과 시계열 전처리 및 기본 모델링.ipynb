# %% [markdown]
#  # 시계열 전처리 및 기본 모델링

# %% [markdown]
# # 1.환경준비

# %% [markdown]
# ## (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as spst
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from sklearn.metrics import *

import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.filterwarnings(action='ignore')
warnings.simplefilter('ignore', ConvergenceWarning)

# %% [markdown]
# ## (2) 데이터 불러오기

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/retail_demand2.csv'
data = pd.read_csv(path, usecols = ['date', 'sales'])
data = data.loc[data['date']<= '2014-10-31'].reset_index(drop = True)
data['date'] = pd.to_datetime(data['date'])
data['weekday'] = data['date'].dt.day_name().str.slice(0,3)
data.head()
# Out:
#         date  sales weekday
# 0 2013-01-01     45     Tue
# 1 2013-01-02     53     Wed
# 2 2013-01-03     65     Thu
# 3 2013-01-04     66     Fri
# 4 2013-01-05     97     Sat

# %% [markdown]
# * 변수 설명
#
#     * date : 날짜
#     * sales : 판매량
#     * weekday : 요일

# %%
plt.figure(figsize = (20,8))
plt.plot(data['sales'])
plt.grid()
plt.show()

# %%
temp = data[-100:]
plt.figure(figsize = (20,8))
plt.plot(temp['sales'], marker ='o')
plt.grid()
plt.show()

# %% [markdown]
# # 2.기본 전처리

# %% [markdown]
# ## (1) y 만들기

# %% [markdown]
# * 사전 관찰(look-ahead) : 미래의 어떤 사실을 안다는 뜻
# * 사전 관찰 문제 :
#     * 데이터를 통해 실제로 알아야 하는 시점보다 더 일찍 미래에 대한 사실을 알게 되는 문제.
#     * 사전관찰 문제가 있는 채로 모델링을 하게 되면, 놀라운 성능의 모델이 만들어짐. --> 그러나 실제로는 불가능한 상황.

# %% [markdown]
# * 그래서 y를 만들때 사전관찰문제가 발생되지 않도록 해야 함.
#     * 예제는 1일 후의 수요량을 예측하려고 합니다.

# %% [markdown]
# * 1일 후 수요량을 예측하려면, y를 어떻게 만들어야 할까요?

# %%
data['y'] = data['sales'].shift(-1)
display(data.head())
display(data.tail())
# Out:
#         date  sales weekday     y
# 0 2013-01-01     45     Tue  53.0
# 1 2013-01-02     53     Wed  65.0
# 2 2013-01-03     65     Thu  66.0
# 3 2013-01-04     66     Fri  97.0
# 4 2013-01-05     97     Sat  83.0
#           date  sales weekday      y
# 664 2014-10-27     89     Mon  101.0
# 665 2014-10-28    101     Tue   92.0
# 666 2014-10-29     92     Wed  107.0
# 667 2014-10-30    107     Thu  119.0
# 668 2014-10-31    119     Fri    NaN

# %%
# 제일 마지막 행은 삭제
data.dropna(axis = 0, inplace = True)
data.tail()
# Out:
#           date  sales weekday      y
# 663 2014-10-26    142     Sun   89.0
# 664 2014-10-27     89     Mon  101.0
# 665 2014-10-28    101     Tue   92.0
# 666 2014-10-29     92     Wed  107.0
# 667 2014-10-30    107     Thu  119.0

# %% [markdown]
# ## (2) 가변수화

# %%
data = pd.get_dummies(data, columns = ['weekday'], drop_first=False)

# %% [markdown]
# ## (3) 데이터 분할

# %% [markdown]
# ### 1) x, y 나누기

# %%
target = 'y'

x = data.drop([target, 'date'], axis = 1) #제거할 때, date도 제거
y = data.loc[:, target]

# %% [markdown]
# ### 2) train, val 분할
# * 1회 분할 : train_test_split( x, y, test_size= , shuffle = False)
#     * test_size : 소수 - 비율, 자연수 - 갯수
#     * shuffle = False : 섞지 말고 데이터 끝에서 test_size 만큼 자르기
# * k-fold cross validation for Time Seires : TimeSeriesSplit

# %%
# 여기서는 1회 분할로 진행합니다.
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 30, shuffle = False)

# %% [markdown]
# # 3.시계열모델링① : ML 기반 모델링

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import *

# %% [markdown]
# ## (1) 모델링

# %%
m1 = LinearRegression()
m1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## (2) 검증

# %%
p1 = m1.predict(x_val)

print('RMSE : ', mean_squared_error(y_val, p1, squared = False))
print('MAE  : ', mean_absolute_error(y_val, p1))
print('MAPE : ', mean_absolute_percentage_error(y_val, p1))
# Out:
# RMSE :  16.250732000710066
# MAE  :  13.42121742935482
# MAPE :  0.12531131106824542

# %% [markdown]
# ## (3) 결과 시각화

# %% [markdown]
# * pred를 시리즈로 바꾸고, 인덱스 맞추기

# %%
p1 = pd.Series(p1, index = y_val.index)
p1.head()
# Out:
# 638     97.777191
# 639    124.168672
# 640    110.697560
# 641    123.954614
# 642     70.729089
# dtype: float64

# %% [markdown]
# * y_train, y_val(전체), pred 한꺼번에 시각화

# %%
plt.figure(figsize = (20,8))
plt.plot(y_train, label = 'train')
plt.plot(y_val, label = 'val')
plt.plot(p1, label = 'pred')

plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(y_val, label = 'val')
plt.plot(p1, label = 'pred')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 4.시계열모델링② : 전통적 시계열 모델링

# %% [markdown]
# ## (1) 모델링

# %%
m2 = sm.tsa.SARIMAX(y_train, order=(4,1,4)).fit()
# sm: statsmodel.api
# tsa: time series analysis

# %% [markdown]
# ## (2) 검증

# %%
p2 = m2.forecast(30) # train 이후 30일 데이터 예측

print('RMSE : ', mean_squared_error(y_val, p2, squared = False))
print('MAE  : ', mean_absolute_error(y_val, p2))
print('MAPE : ', mean_absolute_percentage_error(y_val, p2))
# Out:
# RMSE :  15.17848512755383
# MAE  :  11.650603180164243
# MAPE :  0.11100775090508731

# %% [markdown]
# ## (3) 결과 시각화

# %% [markdown]
# * pred를 시리즈로 바꾸고, 인덱스 맞추기

# %%
p2 = pd.Series(p2, index = y_val.index)

# %% [markdown]
# * y_train, y_val(전체), pred 한꺼번에 시각화

# %%
plt.figure(figsize = (20,8))
plt.plot(y_train, label = 'train')
plt.plot(y_val, label = 'val')
plt.plot(p2, label = 'pred')

plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(y_val, label = 'val')
plt.plot(p2, label = 'pred')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 5.평가 : 잔차분석
#
# * 잔차에 대한 우리의 기대 : 화이트 노이즈
#     * 자기상관성 없음 : ACF, PACF 그래프
#     * 정규분포 : Shapiro-Wilk 검정
#     * 평균과 분산이 일정(Stationary) : ADF 검정
# * 만약 화이트 노이즈가 아니라면...
#     * 더 찾아내야 할 패턴이 있다는 의미.

# %% [markdown]
# ## (1) ACF, PACF
#
# * 정상 데이터 및 자기상관관계가 없는 데이터라면
# * ACF, PACF 그래프에서
#     * 첫번째 lag 에서부터 하늘색 범위 안에 값이 위치해야 하고
#     * 값의 등락에 대한 어떠한 패턴도 보이지 않아야 합니다.
# * 그러나 실제 데이터에서는 그런 결과를 보기 쉽지 않습니다.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
residuals = m2.resid # train set의 오차들

# %% [markdown]
# ### 1) ACF(자기 상관함수)

# %%
plot_acf(residuals, lags = 20)
plt.show()

# %%
res_df = pd.DataFrame({'residuals':residuals})

for i in range(1,21) :
    var = 'lag' + str(i)
    res_df[var] = res_df['residuals'].shift(i)

# %%
res_df.head(20)
# Out:
#     residuals       lag1       lag2       lag3       lag4       lag5  \
# 0   53.000000        NaN        NaN        NaN        NaN        NaN
# 1   12.011866  53.000000        NaN        NaN        NaN        NaN
# 2    7.458530  12.011866  53.000000        NaN        NaN        NaN
# 3   34.286499   7.458530  12.011866  53.000000        NaN        NaN
# 4   10.273136  34.286499   7.458530  12.011866  53.000000        NaN
# 5  -30.062033  10.273136  34.286499   7.458530  12.011866  53.000000
# 6  -11.285513 -30.062033  10.273136  34.286499   7.458530  12.011866
# 7   -0.250528 -11.285513 -30.062033  10.273136  34.286499   7.458530
# 8   13.496519  -0.250528 -11.285513 -30.062033  10.273136  34.286499
# 9  -14.735743  13.496519  -0.250528 -11.285513 -30.062033  10.273136
# 10 -23.678517 -14.735743  13.496519  -0.250528 -11.285513 -30.062033
# 11   5.055621 -23.678517 -14.735743  13.496519  -0.250528 -11.285513
# 12  -7.842773   5.055621 -23.678517 -14.735743  13.496519  -0.250528
# 13   7.162588  -7.842773   5.055621 -23.678517 -14.735743  13.496519
# 14  -6.676052   7.162588  -7.842773   5.055621 -23.678517 -14.735743
# 15  -3.709694  -6.676052   7.162588  -7.842773   5.055621 -23.678517
# 16  -1.583041  -3.709694  -6.676052   7.162588  -7.842773   5.055621
# 17  -6.169598  -1.583041  -3.709694  -6.676052   7.162588  -7.842773
# 18  13.325956  -6.169598  -1.583041  -3.709694  -6.676052   7.162588
# 19 -12.586287  13.325956  -6.169598  -1.583041  -3.709694  -6.676052
#
#          lag6       lag7       lag8       lag9  ...      lag11      lag12  \
# 0         NaN        NaN        NaN        NaN  ...        NaN        NaN
# 1         NaN        NaN        NaN        NaN  ...        NaN        NaN
# 2         NaN        NaN        NaN        NaN  ...        NaN        NaN
# 3         NaN        NaN        NaN        NaN  ...        NaN        NaN
# 4         NaN        NaN        NaN        NaN  ...        NaN        NaN
# 5         NaN        NaN        NaN        NaN  ...        NaN        NaN
# 6   53.000000        NaN        NaN        NaN  ...        NaN        NaN
# 7   12.011866  53.000000        NaN        NaN  ...        NaN        NaN
# 8    7.458530  12.011866  53.000000        NaN  ...        NaN        NaN
# 9   34.286499   7.458530  12.011866  53.000000  ...        NaN        NaN
# 10  10.273136  34.286499   7.458530  12.011866  ...        NaN        NaN
# 11 -30.062033  10.273136  34.286499   7.458530  ...  53.000000        NaN
# 12 -11.285513 -30.062033  10.273136  34.286499  ...  12.011866  53.000000
# 13  -0.250528 -11.285513 -30.062033  10.273136  ...   7.458530  12.011866
# 14  13.496519  -0.250528 -11.285513 -30.062033  ...  34.286499   7.458530
# 15 -14.735743  13.496519  -0.250528 -11.285513  ...  10.273136  34.286499
# 16 -23.678517 -14.735743  13.496519  -0.250528  ... -30.062033  10.273136
# 17   5.055621 -23.678517 -14.735743  13.496519  ... -11.285513 -30.062033
# 18  -7.842773   5.055621 -23.678517 -14.735743  ...  -0.250528 -11.285513
# 19   7.162588  -7.842773   5.055621 -23.678517  ...  13.496519  -0.250528
#
#         lag13      lag14      lag15      lag16      lag17      lag18  lag19  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 11        NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 12        NaN        NaN        NaN        NaN        NaN        NaN    NaN
# 13  53.000000        NaN        NaN        NaN        NaN        NaN    NaN
# 14  12.011866  53.000000        NaN        NaN        NaN        NaN    NaN
# 15   7.458530  12.011866  53.000000        NaN        NaN        NaN    NaN
# 16  34.286499   7.458530  12.011866  53.000000        NaN        NaN    NaN
# 17  10.273136  34.286499   7.458530  12.011866  53.000000        NaN    NaN
# 18 -30.062033  10.273136  34.286499   7.458530  12.011866  53.000000    NaN
# 19 -11.285513 -30.062033  10.273136  34.286499   7.458530  12.011866   53.0
#
#     lag20
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
#
# [20 rows x 21 columns]

# %%
res_df.corr()
# Out:
#            residuals      lag1      lag2      lag3      lag4      lag5  \
# residuals   1.000000 -0.007985 -0.079460  0.101382  0.120750 -0.108291
# lag1       -0.007985  1.000000 -0.008814 -0.081757  0.103704  0.120875
# lag2       -0.079460 -0.008814  1.000000 -0.011112 -0.079787  0.103840
# lag3        0.101382 -0.081757 -0.011112  1.000000 -0.005592 -0.079795
# lag4        0.120750  0.103704 -0.079787 -0.005592  1.000000 -0.005826
# lag5       -0.108291  0.120875  0.103840 -0.079795 -0.005826  1.000000
# lag6       -0.162724 -0.108286  0.120980  0.104263 -0.080145 -0.005831
# lag7        0.324840 -0.161525 -0.106842  0.125675  0.100592 -0.080444
# lag8       -0.178730  0.325211 -0.161344 -0.106501  0.125389  0.100568
# lag9       -0.076483 -0.178325  0.325973 -0.160445 -0.108206  0.125347
# lag10       0.113400 -0.077227 -0.179232  0.325102 -0.159047 -0.108153
# lag11       0.101605  0.113831 -0.076852 -0.178723  0.325025 -0.159109
# lag12      -0.106358  0.100581  0.112714 -0.080312 -0.176243  0.325445
# lag13      -0.139970 -0.107673  0.099412  0.109892 -0.077388 -0.176263
# lag14       0.293962 -0.141931 -0.109750  0.095297  0.114936 -0.077325
# lag15      -0.185328  0.294683 -0.141415 -0.108569  0.094081  0.114893
# lag16      -0.170590 -0.186085  0.294195 -0.143631 -0.107168  0.094180
# lag17       0.097796 -0.172505 -0.188216  0.291182 -0.139970 -0.107158
# lag18       0.118875  0.097699 -0.172739 -0.189150  0.292398 -0.139957
# lag19      -0.090633  0.118562  0.097345 -0.174286 -0.188703  0.292468
# lag20      -0.177051 -0.090605  0.118689  0.097808 -0.174962 -0.188712
#
#                lag6      lag7      lag8      lag9  ...     lag11     lag12  \
# residuals -0.162724  0.324840 -0.178730 -0.076483  ...  0.101605 -0.106358
# lag1      -0.108286 -0.161525  0.325211 -0.178325  ...  0.113831  0.100581
# lag2       0.120980 -0.106842 -0.161344  0.325973  ... -0.076852  0.112714
# lag3       0.104263  0.125675 -0.106501 -0.160445  ... -0.178723 -0.080312
# lag4      -0.080145  0.100592  0.125389 -0.108206  ...  0.325025 -0.176243
# lag5      -0.005831 -0.080444  0.100568  0.125347  ... -0.159109  0.325445
# lag6       1.000000 -0.005947 -0.080464  0.100548  ... -0.108194 -0.159159
# lag7      -0.005947  1.000000 -0.006436 -0.081626  ...  0.124880 -0.106116
# lag8      -0.080464 -0.006436  1.000000 -0.006601  ...  0.102037  0.125376
# lag9       0.100548 -0.081626 -0.006601  1.000000  ... -0.081708  0.102925
# lag10      0.125443  0.102147 -0.081428 -0.006132  ... -0.005788 -0.082851
# lag11     -0.108194  0.124880  0.102037 -0.081708  ...  1.000000 -0.005207
# lag12     -0.159159 -0.106116  0.125376  0.102925  ... -0.005207  1.000000
# lag13      0.325827 -0.157153 -0.105822  0.126325  ... -0.082331 -0.006993
# lag14     -0.176456  0.330301 -0.156891 -0.104886  ...  0.103021 -0.085042
# lag15     -0.077382 -0.177894  0.330199 -0.157330  ...  0.124839  0.103959
# lag16      0.114970 -0.076228 -0.177739  0.330782  ... -0.104147  0.124023
# lag17      0.094440  0.118546 -0.075833 -0.176978  ... -0.157456 -0.106771
# lag18     -0.107150  0.094870  0.118597 -0.075754  ...  0.330088 -0.157803
# lag19     -0.139944 -0.106579  0.095002  0.118882  ... -0.177005  0.329850
# lag20      0.292464 -0.140298 -0.106605  0.094976  ... -0.076163 -0.177066
#
#               lag13     lag14     lag15     lag16     lag17     lag18  \
# residuals -0.139970  0.293962 -0.185328 -0.170590  0.097796  0.118875
# lag1      -0.107673 -0.141931  0.294683 -0.186085 -0.172505  0.097699
# lag2       0.099412 -0.109750 -0.141415  0.294195 -0.188216 -0.172739
# lag3       0.109892  0.095297 -0.108569 -0.143631  0.291182 -0.189150
# lag4      -0.077388  0.114936  0.094081 -0.107168 -0.139970  0.292398
# lag5      -0.176263 -0.077325  0.114893  0.094180 -0.107158 -0.139957
# lag6       0.325827 -0.176456 -0.077382  0.114970  0.094440 -0.107150
# lag7      -0.157153  0.330301 -0.177894 -0.076228  0.118546  0.094870
# lag8      -0.105822 -0.156891  0.330199 -0.177739 -0.075833  0.118597
# lag9       0.126325 -0.104886 -0.157330  0.330782 -0.176978 -0.075754
# lag10      0.101979  0.125089 -0.104441 -0.158003  0.329979 -0.177162
# lag11     -0.082331  0.103021  0.124839 -0.104147 -0.157456  0.330088
# lag12     -0.006993 -0.085042  0.103959  0.124023 -0.106771 -0.157803
# lag13      1.000000 -0.009568 -0.084287  0.103101  0.121910 -0.107079
# lag14     -0.009568  1.000000 -0.008392 -0.085841  0.100045  0.121838
# lag15     -0.084287 -0.008392  1.000000 -0.007929 -0.084840  0.100167
# lag16      0.103101 -0.085841 -0.007929  1.000000 -0.009245 -0.084975
# lag17      0.121910  0.100045 -0.084840 -0.009245  1.000000 -0.009540
# lag18     -0.107079  0.121838  0.100167 -0.084975 -0.009540  1.000000
# lag19     -0.158535 -0.108082  0.122149  0.099898 -0.085879 -0.009604
# lag20      0.330257 -0.158688 -0.108153  0.122234  0.100192 -0.085869
#
#               lag19     lag20
# residuals -0.090633 -0.177051
# lag1       0.118562 -0.090605
# lag2       0.097345  0.118689
# lag3      -0.174286  0.097808
# lag4      -0.188703 -0.174962
# lag5       0.292468 -0.188712
# lag6      -0.139944  0.292464
# lag7      -0.106579 -0.140298
# lag8       0.095002 -0.106605
# lag9       0.118882  0.094976
# lag10     -0.076122  0.118979
# lag11     -0.177005 -0.076163
# lag12      0.329850 -0.177066
# lag13     -0.158535  0.330257
# lag14     -0.108082 -0.158688
# lag15      0.122149 -0.108153
# lag16      0.099898  0.122234
# lag17     -0.085879  0.100192
# lag18     -0.009604 -0.085869
# lag19      1.000000 -0.009575
# lag20     -0.009575  1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# ### 2) PACF

# %%
plot_pacf(residuals, lags = 20)
plt.show()

# %%
lags = 20

fig,ax = plt.subplots(1,2, figsize = (15,5))
plot_acf(residuals, lags = lags, ax = ax[0])
plot_pacf(residuals, lags = lags, ax = ax[1])
plt.show()

# %% [markdown]
# ## (2) 검정
# 검정 도구를 적용하여 의사결정하는 용도로만 사용합니다.

# %%
import scipy.stats as spst
import statsmodels.api as sm

# %% [markdown]
# ### 1) 정규성 검정 : Shapiro-Wilk 검정
#
# * 귀무가설 : **정규 분포이다.** (p-value > 0.05)
# * 대립가설 : 정규분포가 아니다.

# %%
spst.shapiro(residuals)[1]
# Out:
# 0.006060344632714987

# %% [markdown]
# ### 2) 정상성 검정 : ADF 검정
#
# * 귀무가설 : 비정상(Non-Stationary) 데이터이다.
# * 대립가설 : **정상(Stationary) 데이터**이다.(P-value <= 0.05)

# %%
# ADF 테스트
sm.tsa.stattools.adfuller(residuals)[1]
# Out:
# 3.302254779518776e-05

# %% [markdown]
# # 6.함수로 만들기

# %% [markdown]
# ## (1) 결과 시각화

# %%
def plot_model_result(y_train, y_val, pred) :
    pred = pd.Series(pred, index = y_val.index)

    # 전체 시각화
    plt.figure(figsize = (20,12))
    plt.subplot(2,1,1)
    plt.plot(y_train, label = 'train')
    plt.plot(y_val, label = 'val')
    plt.plot(pred, label = 'pred')
    plt.legend()
    plt.grid()

    plt.subplot(2,1,2)
    plt.plot(y_val, label = 'val')
    plt.plot(pred, label = 'pred')
    plt.legend()
    plt.grid()

    plt.show()

# %%
plot_model_result(y_train, y_val, p2)

# %% [markdown]
# ## (2) 잔차분석

# %%
def residual_diag(residuals, lags = 30) :
    print('* 정규성 검정(> 0.05) : ', round(spst.shapiro(residuals)[1],5))
    print('* 정상성 검정(< 0.05) : ', round(sm.tsa.stattools.adfuller(residuals)[1],5))
    print('* 자기상관성 확인(ACF, PACF)')
    fig,ax = plt.subplots(1,2, figsize = (15,5))
    plot_acf(residuals, lags = lags, ax = ax[0])
    plot_pacf(residuals, lags = lags, ax = ax[1])
    plt.show()

# %%
residual_diag(residuals, lags = 30)
# Out:
# * 정규성 검정(> 0.05) :  0.00606
# * 정상성 검정(< 0.05) :  3e-05
# * 자기상관성 확인(ACF, PACF)
